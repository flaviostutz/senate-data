# %% [markdown]
# ### Download PDFs

# %%
import os
if not os.path.exists('output/stj-decisoes'):
    os.makedirs('output/stj-decisoes')

# %%
import modules.downloadutils as downloadutils
import requests
import sys

# r = requests.get('https://ww2.stj.jus.br/websecstj/cgi/revista/REJ.cgi/MON?seq=84181150')
# with open('output/stj-decisoes/test.pdf', 'wb') as file:
#     file.write(r.content)
# print('DONE')

for seq in range(84171450, 84171950):  
    try:
        downloadutils.download_file('https://ww2.stj.jus.br/websecstj/cgi/revista/REJ.cgi/MON?seq=' + str(seq), 'output/stj-decisoes/decisao-' + str(seq) + '.pdf', 'application/pdf')
        sys.stdout.write('.')
    except Exception as e:
        print(str(seq) + ': ' + str(e))
# Out:
# 84171450: Invalid content-type: text/html; charset=ISO-8859-1
# 84171451: Invalid content-type: text/html; charset=ISO-8859-1
# 84171452: Invalid content-type: text/html; charset=ISO-8859-1
# .84171454: Invalid content-type: text/html; charset=ISO-8859-1
# 84171455: Invalid content-type: text/html; charset=ISO-8859-1
# .84171457: Invalid content-type: text/html; charset=ISO-8859-1
# .84171459: Invalid content-type: text/html; charset=ISO-8859-1
# 84171460: Invalid content-type: text/html; charset=ISO-8859-1
# 84171461: Invalid content-type: text/html; charset=ISO-8859-1
# 84171462: Invalid content-type: text/html; charset=ISO-8859-1
# 84171463: Invalid content-type: text/html; charset=ISO-8859-1
# 84171464: Invalid content-type: text/html; charset=ISO-8859-1
# 84171465: Invalid content-type: text/html; charset=ISO-8859-1
# 84171466: Invalid content-type: text/html; charset=ISO-8859-1
# 84171467: Invalid content-type: text/html; charset=ISO-8859-1
# 84171468: Invalid content-type: text/html; charset=ISO-8859-1
# .84171470: Invalid content-type: text/html; charset=ISO-8859-1
# 84171471: Invalid content-type: text/html; charset=ISO-8859-1
# 84171472: Invalid content-type: text/html; charset=ISO-8859-1
# 84171473: Invalid content-type: text/html; charset=ISO-8859-1
# 84171474: Invalid content-type: text/html; charset=ISO-8859-1
# 84171475: Invalid content-type: text/html; charset=ISO-8859-1
# 84171476: Invalid content-type: text/html; charset=ISO-8859-1
# 84171477: Invalid content-type: text/html; charset=ISO-8859-1
# 84171478: Invalid content-type: text/html; charset=ISO-8859-1
# 84171479: Invalid content-type: text/html; charset=ISO-8859-1
# 84171480: Invalid content-type: text/html; charset=ISO-8859-1
# 84171481: Invalid content-type: text/html; charset=ISO-8859-1
# 84171482: Invalid content-type: text/html; charset=ISO-8859-1
# 84171483: Invalid content-type: text/html; charset=ISO-8859-1
# 84171484: Invalid content-type: text/html; charset=ISO-8859-1
# 84171485: Invalid content-type: text/html; charset=ISO-8859-1
# 84171486: Invalid content-type: text/html; charset=ISO-8859-1
# 84171487: Invalid content-type: text/html; charset=ISO-8859-1
# 84171488: Invalid content-type: text/html; charset=ISO-8859-1
# 84171489: Invalid content-type: text/html; charset=ISO-8859-1
# 84171490: Invalid content-type: text/html; charset=ISO-8859-1
# 84171491: Invalid content-type: text/html; charset=ISO-8859-1
# 84171492: Invalid content-type: text/html; charset=ISO-8859-1
# 84171493: Invalid content-type: text/html; charset=ISO-8859-1
# 84171494: Invalid content-type: text/html; charset=ISO-8859-1
# .84171496: Invalid content-type: text/html; charset=ISO-8859-1
# 84171497: Invalid content-type: text/html; charset=ISO-8859-1
# 84171498: Invalid content-type: text/html; charset=ISO-8859-1
# 84171499: Invalid content-type: text/html; charset=ISO-8859-1
# 84171500: Invalid content-type: text/html; charset=ISO-8859-1
# 84171501: Invalid content-type: text/html; charset=ISO-8859-1
# 84171502: Invalid content-type: text/html; charset=ISO-8859-1
# 84171503: Invalid content-type: text/html; charset=ISO-8859-1
# 84171504: Invalid content-type: text/html; charset=ISO-8859-1
# 84171505: Invalid content-type: text/html; charset=ISO-8859-1
# .84171507: Invalid content-type: text/html; charset=ISO-8859-1
# 84171508: Invalid content-type: text/html; charset=ISO-8859-1
# 84171509: Invalid content-type: text/html; charset=ISO-8859-1
# 84171510: Invalid content-type: text/html; charset=ISO-8859-1
# 84171511: Invalid content-type: text/html; charset=ISO-8859-1
# 84171512: Invalid content-type: text/html; charset=ISO-8859-1
# 84171513: Invalid content-type: text/html; charset=ISO-8859-1
# 84171514: Invalid content-type: text/html; charset=ISO-8859-1
# 84171515: Invalid content-type: text/html; charset=ISO-8859-1
# 84171516: Invalid content-type: text/html; charset=ISO-8859-1
# .84171518: Invalid content-type: text/html; charset=ISO-8859-1
# .84171520: Invalid content-type: text/html; charset=ISO-8859-1
# 84171521: Invalid content-type: text/html; charset=ISO-8859-1
# 84171522: Invalid content-type: text/html; charset=ISO-8859-1
# 84171523: Invalid content-type: text/html; charset=ISO-8859-1
# 84171524: Invalid content-type: text/html; charset=ISO-8859-1
# 84171525: Invalid content-type: text/html; charset=ISO-8859-1
# 84171526: Invalid content-type: text/html; charset=ISO-8859-1
# .84171528: Invalid content-type: text/html; charset=ISO-8859-1
# 84171529: Invalid content-type: text/html; charset=ISO-8859-1
# 84171530: Invalid content-type: text/html; charset=ISO-8859-1
# 84171531: Invalid content-type: text/html; charset=ISO-8859-1
# 84171532: Invalid content-type: text/html; charset=ISO-8859-1
# 84171533: Invalid content-type: text/html; charset=ISO-8859-1
# 84171534: Invalid content-type: text/html; charset=ISO-8859-1
# 84171535: Invalid content-type: text/html; charset=ISO-8859-1
# 84171536: Invalid content-type: text/html; charset=ISO-8859-1
# 84171537: Invalid content-type: text/html; charset=ISO-8859-1
# 84171538: Invalid content-type: text/html; charset=ISO-8859-1
# 84171539: Invalid content-type: text/html; charset=ISO-8859-1
# 84171540: Invalid content-type: text/html; charset=ISO-8859-1
# 84171541: Invalid content-type: text/html; charset=ISO-8859-1
# 84171542: Invalid content-type: text/html; charset=ISO-8859-1
# 84171543: Invalid content-type: text/html; charset=ISO-8859-1
# 84171544: Invalid content-type: text/html; charset=ISO-8859-1
# .84171546: Invalid content-type: text/html; charset=ISO-8859-1
# 84171547: Invalid content-type: text/html; charset=ISO-8859-1
# 84171548: Invalid content-type: text/html; charset=ISO-8859-1
# 84171549: Invalid content-type: text/html; charset=ISO-8859-1
# .84171551: Invalid content-type: text/html; charset=ISO-8859-1
# 84171552: Invalid content-type: text/html; charset=ISO-8859-1
# 84171553: Invalid content-type: text/html; charset=ISO-8859-1
# 84171554: Invalid content-type: text/html; charset=ISO-8859-1
# 84171555: Invalid content-type: text/html; charset=ISO-8859-1
# 84171556: Invalid content-type: text/html; charset=ISO-8859-1
# 84171557: Invalid content-type: text/html; charset=ISO-8859-1
# 84171558: Invalid content-type: text/html; charset=ISO-8859-1
# 84171559: Invalid content-type: text/html; charset=ISO-8859-1
# 84171560: Invalid content-type: text/html; charset=ISO-8859-1
# 84171561: Invalid content-type: text/html; charset=ISO-8859-1
# 84171562: Invalid content-type: text/html; charset=ISO-8859-1
# 84171563: Invalid content-type: text/html; charset=ISO-8859-1
# 84171564: Invalid content-type: text/html; charset=ISO-8859-1
# 84171565: Invalid content-type: text/html; charset=ISO-8859-1
# 84171566: Invalid content-type: text/html; charset=ISO-8859-1
# 84171567: Invalid content-type: text/html; charset=ISO-8859-1
# 84171568: Invalid content-type: text/html; charset=ISO-8859-1
# 84171569: Invalid content-type: text/html; charset=ISO-8859-1
# .84171571: Invalid content-type: text/html; charset=ISO-8859-1
# .84171573: Invalid content-type: text/html; charset=ISO-8859-1
# 84171574: Invalid content-type: text/html; charset=ISO-8859-1
# 84171575: Invalid content-type: text/html; charset=ISO-8859-1
# .84171577: Invalid content-type: text/html; charset=ISO-8859-1
# 84171578: Invalid content-type: text/html; charset=ISO-8859-1
# 84171579: Invalid content-type: text/html; charset=ISO-8859-1
# 84171580: Invalid content-type: text/html; charset=ISO-8859-1
# 84171581: Invalid content-type: text/html; charset=ISO-8859-1
# 84171582: Invalid content-type: text/html; charset=ISO-8859-1
# 84171583: Invalid content-type: text/html; charset=ISO-8859-1
# 84171584: Invalid content-type: text/html; charset=ISO-8859-1
# 84171585: Invalid content-type: text/html; charset=ISO-8859-1
# 84171586: Invalid content-type: text/html; charset=ISO-8859-1
# ..84171589: Invalid content-type: text/html; charset=ISO-8859-1
# 84171590: Invalid content-type: text/html; charset=ISO-8859-1
# 84171591: Invalid content-type: text/html; charset=ISO-8859-1
# 84171592: Invalid content-type: text/html; charset=ISO-8859-1
# 84171593: Invalid content-type: text/html; charset=ISO-8859-1
# .84171595: Invalid content-type: text/html; charset=ISO-8859-1
# 84171596: Invalid content-type: text/html; charset=ISO-8859-1
# 84171597: Invalid content-type: text/html; charset=ISO-8859-1
# 84171598: Invalid content-type: text/html; charset=ISO-8859-1
# 84171599: Invalid content-type: text/html; charset=ISO-8859-1
# 84171600: Invalid content-type: text/html; charset=ISO-8859-1
# 84171601: Invalid content-type: text/html; charset=ISO-8859-1
# 84171602: Invalid content-type: text/html; charset=ISO-8859-1
# ..84171605: Invalid content-type: text/html; charset=ISO-8859-1
# 84171606: Invalid content-type: text/html; charset=ISO-8859-1
# 84171607: Invalid content-type: text/html; charset=ISO-8859-1
# 84171608: Invalid content-type: text/html; charset=ISO-8859-1
# 84171609: Invalid content-type: text/html; charset=ISO-8859-1
# 84171610: Invalid content-type: text/html; charset=ISO-8859-1
# 84171611: Invalid content-type: text/html; charset=ISO-8859-1
# 84171612: Invalid content-type: text/html; charset=ISO-8859-1
# 84171613: Invalid content-type: text/html; charset=ISO-8859-1
# 84171614: Invalid content-type: text/html; charset=ISO-8859-1
# 84171615: Invalid content-type: text/html; charset=ISO-8859-1
# 84171616: Invalid content-type: text/html; charset=ISO-8859-1
# .84171618: Invalid content-type: text/html; charset=ISO-8859-1
# 84171619: Invalid content-type: text/html; charset=ISO-8859-1
# 84171620: Invalid content-type: text/html; charset=ISO-8859-1
# 84171621: Invalid content-type: text/html; charset=ISO-8859-1
# .84171623: Invalid content-type: text/html; charset=ISO-8859-1
# 84171624: Invalid content-type: text/html; charset=ISO-8859-1
# 84171625: Invalid content-type: text/html; charset=ISO-8859-1
# 84171626: Invalid content-type: text/html; charset=ISO-8859-1
# .84171628: Invalid content-type: text/html; charset=ISO-8859-1
# 84171629: Invalid content-type: text/html; charset=ISO-8859-1
# 84171630: Invalid content-type: text/html; charset=ISO-8859-1
# .84171632: Invalid content-type: text/html; charset=ISO-8859-1
# 84171633: Invalid content-type: text/html; charset=ISO-8859-1
# 84171634: Invalid content-type: text/html; charset=ISO-8859-1
# 84171635: Invalid content-type: text/html; charset=ISO-8859-1
# 84171636: Invalid content-type: text/html; charset=ISO-8859-1
# 84171637: Invalid content-type: text/html; charset=ISO-8859-1
# 84171638: Invalid content-type: text/html; charset=ISO-8859-1
# 84171639: Invalid content-type: text/html; charset=ISO-8859-1
# 84171640: Invalid content-type: text/html; charset=ISO-8859-1
# 84171641: Invalid content-type: text/html; charset=ISO-8859-1
# 84171642: Invalid content-type: text/html; charset=ISO-8859-1
# 84171643: Invalid content-type: text/html; charset=ISO-8859-1
# 84171644: Invalid content-type: text/html; charset=ISO-8859-1
# 84171645: Invalid content-type: text/html; charset=ISO-8859-1
# 84171646: Invalid content-type: text/html; charset=ISO-8859-1
# 84171647: Invalid content-type: text/html; charset=ISO-8859-1
# 84171648: Invalid content-type: text/html; charset=ISO-8859-1
# 84171649: Invalid content-type: text/html; charset=ISO-8859-1
# 84171650: Invalid content-type: text/html; charset=ISO-8859-1
# 84171651: Invalid content-type: text/html; charset=ISO-8859-1
# 84171652: Invalid content-type: text/html; charset=ISO-8859-1
# 84171653: Invalid content-type: text/html; charset=ISO-8859-1
# 84171654: Invalid content-type: text/html; charset=ISO-8859-1
# 84171655: Invalid content-type: text/html; charset=ISO-8859-1
# 84171656: Invalid content-type: text/html; charset=ISO-8859-1
# 84171657: Invalid content-type: text/html; charset=ISO-8859-1
# 84171658: Invalid content-type: text/html; charset=ISO-8859-1
# 84171659: Invalid content-type: text/html; charset=ISO-8859-1
# 84171660: Invalid content-type: text/html; charset=ISO-8859-1
# 84171661: Invalid content-type: text/html; charset=ISO-8859-1
# 84171662: Invalid content-type: text/html; charset=ISO-8859-1
# .84171664: Invalid content-type: text/html; charset=ISO-8859-1
# .84171666: Invalid content-type: text/html; charset=ISO-8859-1
# 84171667: Invalid content-type: text/html; charset=ISO-8859-1
# 84171668: Invalid content-type: text/html; charset=ISO-8859-1
# 84171669: Invalid content-type: text/html; charset=ISO-8859-1
# 84171670: Invalid content-type: text/html; charset=ISO-8859-1
# 84171671: Invalid content-type: text/html; charset=ISO-8859-1
# 84171672: Invalid content-type: text/html; charset=ISO-8859-1
# 84171673: Invalid content-type: text/html; charset=ISO-8859-1
# ..84171676: Invalid content-type: text/html; charset=ISO-8859-1
# 84171677: Invalid content-type: text/html; charset=ISO-8859-1
# 84171678: Invalid content-type: text/html; charset=ISO-8859-1
# 84171679: Invalid content-type: text/html; charset=ISO-8859-1
# ..84171682: Invalid content-type: text/html; charset=ISO-8859-1
# 84171683: Invalid content-type: text/html; charset=ISO-8859-1
# 84171684: Invalid content-type: text/html; charset=ISO-8859-1
# 84171685: Invalid content-type: text/html; charset=ISO-8859-1
# 84171686: Invalid content-type: text/html; charset=ISO-8859-1
# 84171687: Invalid content-type: text/html; charset=ISO-8859-1
# 84171688: Invalid content-type: text/html; charset=ISO-8859-1
# 84171689: Invalid content-type: text/html; charset=ISO-8859-1
# 84171690: Invalid content-type: text/html; charset=ISO-8859-1
# 84171691: Invalid content-type: text/html; charset=ISO-8859-1
# 84171692: Invalid content-type: text/html; charset=ISO-8859-1
# 84171693: Invalid content-type: text/html; charset=ISO-8859-1
# 84171694: Invalid content-type: text/html; charset=ISO-8859-1
# 84171695: Invalid content-type: text/html; charset=ISO-8859-1
# .84171697: Invalid content-type: text/html; charset=ISO-8859-1
# 84171698: Invalid content-type: text/html; charset=ISO-8859-1
# 84171699: Invalid content-type: text/html; charset=ISO-8859-1
# 84171700: Invalid content-type: text/html; charset=ISO-8859-1
# 84171701: Invalid content-type: text/html; charset=ISO-8859-1
# 84171702: Invalid content-type: text/html; charset=ISO-8859-1
# .84171704: Invalid content-type: text/html; charset=ISO-8859-1
# 84171705: Invalid content-type: text/html; charset=ISO-8859-1
# 84171706: Invalid content-type: text/html; charset=ISO-8859-1
# 84171707: Invalid content-type: text/html; charset=ISO-8859-1
# 84171708: Invalid content-type: text/html; charset=ISO-8859-1
# 84171709: Invalid content-type: text/html; charset=ISO-8859-1
# 84171710: Invalid content-type: text/html; charset=ISO-8859-1
# 84171711: Invalid content-type: text/html; charset=ISO-8859-1
# .84171713: Invalid content-type: text/html; charset=ISO-8859-1
# 84171714: Invalid content-type: text/html; charset=ISO-8859-1
# .84171716: Invalid content-type: text/html; charset=ISO-8859-1
# .84171718: Invalid content-type: text/html; charset=ISO-8859-1
# .84171720: Invalid content-type: text/html; charset=ISO-8859-1
# 84171721: Invalid content-type: text/html; charset=ISO-8859-1
# .84171723: Invalid content-type: text/html; charset=ISO-8859-1
# 84171724: Invalid content-type: text/html; charset=ISO-8859-1
# 84171725: Invalid content-type: text/html; charset=ISO-8859-1
# 84171726: Invalid content-type: text/html; charset=ISO-8859-1
# 84171727: Invalid content-type: text/html; charset=ISO-8859-1
# 84171728: Invalid content-type: text/html; charset=ISO-8859-1
# 84171729: Invalid content-type: text/html; charset=ISO-8859-1
# 84171730: Invalid content-type: text/html; charset=ISO-8859-1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.4/dist-packages/requests/packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             try:  # Python 2.7, use buffering of HTTP responses
# --> 379                 httplib_response = conn.getresponse(buffering=True)
#     380             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-6be8b560d4c9> in <module>()
#      10 for seq in range(84171450, 84171950):
#      11     try:
# ---> 12         downloadutils.download_file('https://ww2.stj.jus.br/websecstj/cgi/revista/REJ.cgi/MON?seq=' + str(seq), 'output/stj-decisoes/decisao-' + str(seq) + '.pdf', 'application/pdf')
#      13         sys.stdout.write('.')
#      14     except Exception as e:
#
# /notebooks/modules/downloadutils.py in download_file(url, output_file, expected_content_type)
#       2
#       3 def download_file(url, output_file, expected_content_type):
# ----> 4     r = requests.get(url)
#       5     r.raise_for_status()
#       6     if r.headers['Content-Type'] == expected_content_type:
#
# /usr/local/lib/python3.4/dist-packages/requests/api.py in get(url, params, **kwargs)
#      68
#      69     kwargs.setdefault('allow_redirects', True)
# ---> 70     return request('get', url, params=params, **kwargs)
#      71
#      72
#
# /usr/local/lib/python3.4/dist-packages/requests/api.py in request(method, url, **kwargs)
#      54     # cases, and look like a memory leak in others.
#      55     with sessions.Session() as session:
# ---> 56         return session.request(method=method, url=url, **kwargs)
#      57
#      58
#
# /usr/local/lib/python3.4/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     486         }
#     487         send_kwargs.update(settings)
# --> 488         resp = self.send(prep, **send_kwargs)
#     489
#     490         return resp
#
# /usr/local/lib/python3.4/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     607
#     608         # Send the request
# --> 609         r = adapter.send(request, **kwargs)
#     610
#     611         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.4/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     421                     decode_content=False,
#     422                     retries=self.max_retries,
# --> 423                     timeout=timeout
#     424                 )
#     425
#
# /usr/local/lib/python3.4/dist-packages/requests/packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# /usr/local/lib/python3.4/dist-packages/requests/packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     380             except TypeError:  # Python 2.6 and older, Python 3
#     381                 try:
# --> 382                     httplib_response = conn.getresponse()
#     383                 except Exception as e:
#     384                     # Remove the TypeError from the exception chain in Python 3;
#
# /usr/lib/python3.4/http/client.py in getresponse(self)
#    1206
#    1207         try:
# -> 1208             response.begin()
#    1209             assert response.will_close != _UNKNOWN
#    1210             self.__state = _CS_IDLE
#
# /usr/lib/python3.4/http/client.py in begin(self)
#     378         # read until we get a non-100 response
#     379         while True:
# --> 380             version, status, reason = self._read_status()
#     381             if status != CONTINUE:
#     382                 break
#
# /usr/lib/python3.4/http/client.py in _read_status(self)
#     340
#     341     def _read_status(self):
# --> 342         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     343         if len(line) > _MAXLINE:
#     344             raise LineTooLong("status line")
#
# /usr/lib/python3.4/socket.py in readinto(self, b)
#     372         while True:
#     373             try:
# --> 374                 return self._sock.recv_into(b)
#     375             except timeout:
#     376                 self._timeout_occurred = True
#
# /usr/lib/python3.4/ssl.py in recv_into(self, buffer, nbytes, flags)
#     767                   "non-zero flags not allowed in calls to recv_into() on %s" %
#     768                   self.__class__)
# --> 769             return self.read(nbytes, buffer)
#     770         else:
#     771             return socket.recv_into(self, buffer, nbytes, flags)
#
# /usr/lib/python3.4/ssl.py in read(self, len, buffer)
#     639         try:
#     640             if buffer is not None:
# --> 641                 v = self._sslobj.read(len, buffer)
#     642             else:
#     643                 v = self._sslobj.read(len or 1024)
#
# KeyboardInterrupt:
