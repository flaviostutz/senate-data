# %% [markdown]
# ### Download speeches

# %%
import os
if not os.path.exists('output/speeches'):
    os.makedirs('output/speeches')
    
# FROM_DATE = 20180401
# TO_DATE = 20180431

# %%
import modules.senatedownloader as sd
sd.download_senate_speeches('20180401', '20180431', 'output/speeches/senate-speeches-201804.csv', max=None)
# Out:
# ...
# ............................................................................................................................................................................................................................................................................Traceback (most recent call last):
#   File "/notebooks/modules/senatedownloader.py", line 120, in download_senate_speeches
#     url = pron['TextoIntegral']
# TypeError: string indices must be integers
# exception string indices must be integers
# Traceback (most recent call last):
#   File "/notebooks/modules/senatedownloader.py", line 120, in download_senate_speeches
#     url = pron['TextoIntegral']
# TypeError: string indices must be integers
# exception string indices must be integers
# Traceback (most recent call last):
#   File "/notebooks/modules/senatedownloader.py", line 120, in download_senate_speeches
#     url = pron['TextoIntegral']
# TypeError: string indices must be integers
# ...
