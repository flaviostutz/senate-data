# %% [markdown]
# ### Download speeches

# %%
import urllib.request
import xml.etree.ElementTree as ET
import csv
import re
import sys
import matplotlib.pyplot as plt

TAG_RE = re.compile(r'<[^>]+>')
SPACE_RE = re.compile('&nbsp;')

# %%
import pandas as pd
import numpy as np

SENATOR_ID = 945
MAX_SPEECHES = 300
f = urllib.request.urlopen("http://legis.senado.leg.br/dadosabertos/senador/"+ str(SENATOR_ID) +"/discursos")
raw = f.read()
root = ET.fromstring(raw)

print("Downloading speeches ")
parlamentar = root.find('Parlamentar')
i = 0

data = []

alltexts = ''
with open("output/senator-speeches.csv", "w", encoding='utf-8') as ofile:
    writer = csv.writer(ofile, delimiter=',', quotechar='"', quoting=csv.QUOTE_ALL)
    id = parlamentar.find("IdentificacaoParlamentar")
    for pr in parlamentar.find("Pronunciamentos").iter('Pronunciamento'):
        i = i + 1
        try:
    #         http://www25.senado.leg.br/web/atividade/pronunciamentos/-/p/texto/427686
            urlTexto = pr.find('UrlTexto').text
            f = urllib.request.urlopen(urlTexto)
            html = f.read().decode('utf-8')
    #         print('>>>' + html)

            html_frag = re.search('texto-integral">(.*)<div class="FooterMain"', html)
            if html_frag != None:
                text = TAG_RE.sub('', html_frag.group(1))
                text = SPACE_RE.sub('', text)
        #         print(text)

                row = [ id.find('CodigoParlamentar').text,
                        id.find('NomeParlamentar').text,
                        id.find('SexoParlamentar').text,
                        pr.find('SiglaTipoPronunciamento').text,
                        pr.find('DataPronunciamento').text,
                        pr.find('SiglaPartidoParlamentarNaData').text,
                        pr.find('UfParlamentarNaData').text,
                        pr.find('NomeCasaPronunciamento').text,
                        text,
                      ]
                writer.writerow(row)
        #         print('>>>> ' + text)
                alltexts = alltexts + '\n' + text
                data.append(text)
        #         print("speech " + row[1] + " " + row[4])
                sys.stdout.write('.')
            else:
                print("Unavailable " + urlTexto)

            if i > MAX_SPEECHES:
                break
        except Exception as e:
            print('exception ' + str(e))
            if i > MAX_SPEECHES:
                break

speeches = data

print("Done " + len(speeches))
# Out:
# Downloading speeches
# ...................................................................Unavailable http://www25.senado.leg.br/web/atividade/pronunciamentos/-/p/texto/13340
# Unavailable http://www25.senado.leg.br/web/atividade/pronunciamentos/-/p/texto/13677
# Unavailable http://www25.senado.leg.br/web/atividade/pronunciamentos/-/p/texto/13374
# Unavailable http://www25.senado.leg.br/web/atividade/pronunciamentos/-/p/texto/13385
# Unavailable http://www25.senado.leg.br/web/atividade/pronunciamentos/-/p/texto/14489
# Unavailable http://www25.senado.leg.br/web/atividade/pronunciamentos/-/p/texto/13417
# Unavailable http://www25.senado.leg.br/web/atividade/pronunciamentos/-/p/texto/13421
# Unavailable http://www25.senado.leg.br/web/atividade/pronunciamentos/-/p/texto/15568
# Unavailable http://www25.senado.leg.br/web/atividade/pronunciamentos/-/p/texto/13447
# Unavailable http://www25.senado.leg.br/web/atividade/pronunciamentos/-/p/texto/14533
# Unavailable http://www25.senado.leg.br/web/atividade/pronunciamentos/-/p/texto/14390
# Unavailable http://www25.senado.leg.br/web/atividade/pronunciamentos/-/p/texto/13504
# Unavailable http://www25.senado.leg.br/web/atividade/pronunciamentos/-/p/texto/14413
# Unavailable http://www25.senado.leg.br/web/atividade/pronunciamentos/-/p/texto/15653
# Unavailable http://www25.senado.leg.br/web/atividade/pronunciamentos/-/p/texto/15664
# Unavailable http://www25.senado.leg.br/web/atividade/pronunciamentos/-/p/texto/16062
# Unavailable http://www25.senado.leg.br/web/atividade/pronunciamentos/-/p/texto/13220
# Unavailable http://www25.senado.leg.br/web/atividade/pronunciamentos/-/p/texto/13228
# Unavailable http://www25.senado.leg.br/web/atividade/pronunciamentos/-/p/texto/14203
# Unavailable http://www25.senado.leg.br/web/atividade/pronunciamentos/-/p/texto/13260
# Unavailable http://www25.senado.leg.br/web/atividade/pronunciamentos/-/p/texto/15382
# Unavailable http://www25.senado.leg.br/web/atividade/pronunciamentos/-/p/texto/15390
# Unavailable http://www25.senado.leg.br/web/atividade/pronunciamentos/-/p/texto/13703
# Unavailable http://www25.senado.leg.br/web/atividade/pronunciamentos/-/p/texto/16838
# Unavailable http://www25.senado.leg.br/web/atividade/pronunciamentos/-/p/texto/16219
# Unavailable http://www25.senado.leg.br/web/atividade/pronunciamentos/-/p/texto/16263
# Unavailable http://www25.senado.leg.br/web/atividade/pronunciamentos/-/p/texto/13761
# Unavailable http://www25.senado.leg.br/web/atividade/pronunciamentos/-/p/texto/13762
# Unavailable http://www25.senado.leg.br/web/atividade/pronunciamentos/-/p/texto/13772
# Unavailable http://www25.senado.leg.br/web/atividade/pronunciamentos/-/p/texto/15170
# Unavailable http://www25.senado.leg.br/web/atividade/pronunciamentos/-/p/texto/15476
# Unavailable http://www25.senado.leg.br/web/atividade/pronunciamentos/-/p/texto/17244
# Unavailable http://www25.senado.leg.br/web/atividade/pronunciamentos/-/p/texto/16882
# Unavailable http://www25.senado.leg.br/web/atividade/pronunciamentos/-/p/texto/17261
# Unavailable http://www25.senado.leg.br/web/atividade/pronunciamentos/-/p/texto/14879
# Unavailable http://www25.senado.leg.br/web/atividade/pronunciamentos/-/p/texto/14125
# Unavailable http://www25.senado.leg.br/web/atividade/pronunciamentos/-/p/texto/15211
# Unavailable http://www25.senado.leg.br/web/atividade/pronunciamentos/-/p/texto/16991
# Unavailable http://www25.senado.leg.br/web/atividade/pronunciamentos/-/p/texto/17625
# Unavailable http://www25.senado.leg.br/web/atividade/pronunciamentos/-/p/texto/14924
# Unavailable http://www25.senado.leg.br/web/atividade/pronunciamentos/-/p/texto/14937
# Unavailable http://www25.senado.leg.br/web/atividade/pronunciamentos/-/p/texto/13882
# Unavailable http://www25.senado.leg.br/web/atividade/pronunciamentos/-/p/texto/18328
# Unavailable http://www25.senado.leg.br/web/atividade/pronunciamentos/-/p/texto/16398
# Unavailable http://www25.senado.leg.br/web/atividade/pronunciamentos/-/p/texto/16415
# Unavailable http://www25.senado.leg.br/web/atividade/pronunciamentos/-/p/texto/13919
# Unavailable http://www25.senado.leg.br/web/atividade/pronunciamentos/-/p/texto/16449
# Unavailable http://www25.senado.leg.br/web/atividade/pronunciamentos/-/p/texto/17410
# Unavailable http://www25.senado.leg.br/web/atividade/pronunciamentos/-/p/texto/19077
# Unavailable http://www25.senado.leg.br/web/atividade/pronunciamentos/-/p/texto/17791
# Unavailable http://www25.senado.leg.br/web/atividade/pronunciamentos/-/p/texto/17818
# Unavailable http://www25.senado.leg.br/web/atividade/pronunciamentos/-/p/texto/18141
# Unavailable http://www25.senado.leg.br/web/atividade/pronunciamentos/-/p/texto/17838
# Unavailable http://www25.senado.leg.br/web/atividade/pronunciamentos/-/p/texto/18159
# Unavailable http://www25.senado.leg.br/web/atividade/pronunciamentos/-/p/texto/17953
# ..Unavailable http://www25.senado.leg.br/web/atividade/pronunciamentos/-/p/texto/13641
# exception <urlopen error [Errno 111] Connection refused>
# .........................Unavailable http://www25.senado.leg.br/web/atividade/pronunciamentos/-/p/texto/13315
# .....Unavailable http://www25.senado.leg.br/web/atividade/pronunciamentos/-/p/texto/13457
# Unavailable http://www25.senado.leg.br/web/atividade/pronunciamentos/-/p/texto/13479
# ....Unavailable http://www25.senado.leg.br/web/atividade/pronunciamentos/-/p/texto/15802
# Unavailable http://www25.senado.leg.br/web/atividade/pronunciamentos/-/p/texto/13828
# Unavailable http://www25.senado.leg.br/web/atividade/pronunciamentos/-/p/texto/13861
# Unavailable http://www25.senado.leg.br/web/atividade/pronunciamentos/-/p/texto/15014
# Unavailable http://www25.senado.leg.br/web/atividade/pronunciamentos/-/p/texto/17083
# Unavailable http://www25.senado.leg.br/web/atividade/pronunciamentos/-/p/texto/13172
# Unavailable http://www25.senado.leg.br/web/atividade/pronunciamentos/-/p/texto/13221
# Unavailable http://www25.senado.leg.br/web/atividade/pronunciamentos/-/p/texto/14261
# Unavailable http://www25.senado.leg.br/web/atividade/pronunciamentos/-/p/texto/14306
# Unavailable http://www25.senado.leg.br/web/atividade/pronunciamentos/-/p/texto/17463
# Unavailable http://www25.senado.leg.br/web/atividade/pronunciamentos/-/p/texto/14334
# Unavailable http://www25.senado.leg.br/web/atividade/pronunciamentos/-/p/texto/15577
# ..Unavailable http://www25.senado.leg.br/web/atividade/pronunciamentos/-/p/texto/17425
# ..exception <urlopen error [Errno 111] Connection refused>
# .....................Unavailable http://www25.senado.leg.br/web/atividade/pronunciamentos/-/p/texto/14181
# ..Unavailable http://www25.senado.leg.br/web/atividade/pronunciamentos/-/p/texto/13922
# Unavailable http://www25.senado.leg.br/web/atividade/pronunciamentos/-/p/texto/14870
# ................................exception <urlopen error [Errno 111] Connection refused>
# .............................................................Done

# %% [markdown]
# ### Cleanup and tokenize documents words

# %%
# %%prun
import modules.nlputils as nlputils
stopwords = set([line.strip() for line in open('stopwords.txt', 'r', encoding='utf-8')])
# stopwords = []

tokens = tokenize_filter_stem(speeches, stopwords, min_size=3, filter_regex='[a-z]', stem_language='portuguese', stem_complete=True, only_nouns=True)
print([len(a) for a in tokens])
# Out:
# [166, 203, 509, 273, 825, 585, 285, 228, 74, 113, 613, 344, 444, 428, 891, 307, 310, 206, 112, 367, 281, 204, 593, 675, 444, 502, 318, 194, 646, 228, 520, 361, 749, 405, 330, 331, 347, 237, 224, 315, 284, 583, 392, 665, 457, 443, 449, 310, 323, 361, 756, 225, 311, 596, 144, 1349, 632, 507, 331, 285, 176, 282, 715, 78, 70, 22, 306, 508, 575, 474, 260, 19, 437, 451, 92, 509, 208, 426, 575, 199, 658, 131, 463, 555, 54, 607, 489, 499, 96, 458, 108, 515, 163, 331, 423, 406, 215, 470, 110, 151, 501, 390, 488, 158, 97, 404, 366, 95, 41, 139, 416, 460, 129, 99, 173, 111, 393, 353, 554, 794, 394, 135, 143, 358, 5, 134, 655, 431, 112, 235, 413, 493, 360, 364, 48, 330, 480, 155, 947, 716, 146, 269, 451, 572, 376, 616, 342, 219, 421, 608, 539, 136, 438, 458, 337, 242, 107, 462, 26, 254, 539, 210, 202, 721, 173, 354, 27, 52, 413, 466, 33, 477, 310, 142, 511, 391, 34, 312, 35, 18, 78, 119, 20, 20, 20, 419, 374, 422, 570, 259, 155, 328, 158, 25, 18, 418, 774, 158, 322, 20, 81, 349, 126, 128, 26, 338, 134, 473, 505, 82, 148, 20, 90, 467, 503, 396, 115, 444, 197, 397, 210, 24, 31]

# %%
from wordcloud import WordCloud

def plot_wordcloud(words):
    text = ''
    text = ' '.join(list(words))
    wordcloud = WordCloud(max_font_size=40, random_state=42).generate(text)
    plt.figure(figsize=(10, 10))
    plt.imshow(wordcloud, interpolation="bilinear")
    plt.axis("off")
    plt.show()

# %%
tt = []
for t in tokens:
    for a in t:
        tt.append(a)
plot_wordcloud(tt)

# %% [markdown]
# ### Explore LDA topic modeling

# %%
import gensim
from gensim import corpora, models

dictionary = corpora.Dictionary(tokens)
corpus = [dictionary.doc2bow(text) for text in tokens]
lda_model = gensim.models.ldamodel.LdaModel(corpus, num_topics=4, id2word=dictionary, passes=100)
print(lda_model)
# Out:
# LdaModel(num_terms=10805, num_topics=4, decay=0.5, chunksize=2000)

# %%
lda_model.print_topics(4)
# Out:
# [(0,
#   '0.041*"que" + 0.018*"com" + 0.018*"para" + 0.012*"não" + 0.010*"uma" + 0.009*"governo" + 0.008*"por" + 0.007*"país" + 0.007*"pelo" + 0.007*"empresa"'),
#  (1,
#   '0.026*"que" + 0.014*"com" + 0.012*"banco" + 0.011*"estado" + 0.011*"públicos" + 0.009*"para" + 0.009*"pelo" + 0.007*"paraná" + 0.007*"dos" + 0.007*"governo"'),
#  (2,
#   '0.045*"que" + 0.019*"com" + 0.017*"não" + 0.013*"para" + 0.011*"governo" + 0.010*"presidente" + 0.009*"sr." + 0.009*"uma" + 0.008*"por" + 0.008*"senador"'),
#  (3,
#   '0.045*"que" + 0.018*"com" + 0.014*"para" + 0.014*"não" + 0.010*"uma" + 0.010*"senador" + 0.009*"dos" + 0.008*"por" + 0.008*"exª" + 0.008*"sr."')]
